# %% [markdown]
# # Japheth Ehijie Eromon MARCH Cohort DAF

# %% [markdown]
# # Exploratory Data Analysis of Supermarket Stores Branches Sales
#
# This dataset contains 896 rows analyzing Stores sales and their dependence on stores area and daily customer count.

# %%
# importing necessary libraries
import numpy as np
import pandas as pd

# for visuals
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
df = pd.read_csv(r'C:\Users\User\Desktop\As a Data Analyst\Quantum Analytics\Projects\FINAL PROJECTS\Python Projects\Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# # Data Inspection

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.shape
# Out:
# (896, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
# Checking for duplicates
df.duplicated().value_counts()
# Out:
# False    896
# dtype: int64

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %% [markdown]
# ### Obersvation
# The data looks clean as there are no null values, no duplicates either

# %% [markdown]
# # Data Visualization

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
# Creating a Scatter plot chart to visualize Store Area Vs Store Sales
df.plot.scatter(x = 'Store_Area', y = 'Store_Sales', figsize=(10,6))

# label the axis
plt.xlabel('Store_Area')
plt.ylabel('Store_Sales')

# set the title
plt.title('Store Area Vs Store Sales')

# show the visual
plt.show()

# %%
# Creating a boxplot chart to visualize Items Available, Daily Customer Count and Store Sales
plt.figure(figsize=(10, 6))
sns.boxplot(df[['Items_Available', 'Daily_Customer_Count', 'Store_Sales']])

# set the title
plt.title('Items Available, Daily Customer Count, and Store Sales')

# show the visual
plt.show()

# %%
# Calculate correlations between variables
correlations = df.corr()
print(correlations)
# Out:
#                       Store ID   Store_Area  Items_Available  \
# Store ID               1.000000   -0.058705        -0.055707
# Store_Area            -0.058705    1.000000         0.998891
# Items_Available       -0.055707    0.998891         1.000000
# Daily_Customer_Count  -0.010029   -0.041423        -0.040978
# Store_Sales            0.071486    0.097474         0.098849
#
#                       Daily_Customer_Count  Store_Sales
# Store ID                         -0.010029     0.071486
# Store_Area                       -0.041423     0.097474
# Items_Available                  -0.040978     0.098849
# Daily_Customer_Count              1.000000     0.008629
# Store_Sales                       0.008629     1.000000

# %%
# Creating a Heatmap to visualize Correlations between the variables
plt.figure(figsize=(10, 6))
sns.heatmap(correlations, annot=True, cmap='hot')

# set the titel
plt.title('Correlation Heatmap')

# Plot the visual 
plt.show()

# %%
# Creating a Scatter plot chart to visualize Items Available Vs Store Sales
df.plot.scatter(x = 'Items_Available', y = 'Store_Sales', figsize=(10,6))

# label the axis
plt.xlabel('Items_Available')
plt.ylabel('Store_Sales')

# set the title
plt.title('Items Available Vs Store Sales')

# show the visual
plt.show()

# %%
# Plot a Scatter plot for Store Sales by Items Available and Store Area
plt.scatter(df['Store_Area'], df['Items_Available'], c=df['Store_Sales'])

#Add labels and title
plt.xlabel('Store Area')
plt.ylabel('Items Available')
plt.colorbar(label='Store Sales')

#Show Plot
plt.show()

# %%
# Plot scatter plot
df.plot.scatter('Items_Available', 'Store_Area', figsize=(10,6))



# Add labels and title
plt.xlabel('Items Available')
plt.ylabel('Store Area')
plt.title('Store Area Vs Items Available')


# Show plot
plt.show()

# %%
# Plot scatter plot
df.plot.scatter('Daily_Customer_Count', 'Store_Sales', figsize=(10,6))



# Add labels and title
plt.xlabel('Daily Customer Count')
plt.ylabel('Store Sales')
plt.title('Daily Customer Count Vs Store Sales')


# Show plot
plt.show()
